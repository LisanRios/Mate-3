# %%
from datetime import date
from sklearn.impute import SimpleImputer
import numpy as np
import seaborn as sns

df = pd.read_csv('archs/estudiantes2.csv')


imputer = imputer.fit(df.iloc[:, 1:3])
df.iloc[:, 1:3] = imputer.transform(df.iloc[:, 1:3])
df

desc1 = df.describe()
desc1

desc2=df.describe()

pd.concat([desc1,desc2], axis=1)

Q1 = df['time_study'].quantile(0.25)
Q3 = df['time_study'].quantile(0.75)
IQR = Q3 - Q1
# Definir límites para identificar valores atípicos
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR
# Identificar valores atípicos
valores_atipicos = df[(df['time_study'] < limite_inferior) | (df['time_study'] > limite_superior)]
print("El valor del IRQ es: ", IQR)
print("El valor del límite inferior es :", limite_inferior)
print("El valor del límite superior es :", limite_superior)
print("Valores Atípicos Detectados :", valores_atipicos)
imputer = SimpleImputer(missing_values = np.nan, strategy="mean")

imputer = imputer.fit(df.iloc[:, 1:3])
df.iloc[:, 1:3] = imputer.transform(df.iloc[:, 1:3])
df
# Out:
# El valor del IRQ es:  4.077
# El valor del límite inferior es : -3.99375
# El valor del límite superior es : 12.314250000000001
# Valores Atípicos Detectados :     number_courses  time_study   Marks
# 4                8      70.811  55.299
# 77               8      50.985  38.278
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8      70.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
from datetime import date
from sklearn.impute import SimpleImputer
import numpy as np
import seaborn as sns
df = pd.read_csv('archs/estudiantes2.csv')
df

df.head()

X = df.iloc[:, :-1].values
print(X)

y = df.iloc[:, 2].values
print(y)
# Out:
# [[ 3.     4.508]
#  [ 4.     0.096]
#  [ 4.     3.133]
#  [ 6.     7.909]
#  [ 8.    70.811]
#  [ 6.     3.211]
#  [ 3.     6.063]
#  [ 5.     3.413]
#  [ 4.     4.41 ]
#  [ 3.     6.173]
#  [ 3.     7.353]
#  [ 7.     0.423]
#  [ 7.     4.218]
#  [ 3.     4.274]
#  [ 3.     2.908]
#  [ 4.     4.26 ]
#  [ 5.     5.719]
#  [ 8.     6.08 ]
#  [ 6.     7.711]
#  [ 8.     3.977]
#  [ 4.       nan]
#  [ 6.     6.126]
#  [ 5.     2.051]
#  [ 7.     4.875]
#  [ 4.     3.635]
#  [ 3.     1.407]
#  [ 7.     0.508]
#  [ 8.     4.378]
#  [ 5.     0.156]
#  [ 4.     1.299]
#  [ 8.     3.864]
#  [ 3.     1.923]
#  [ 8.     0.932]
#  [ 6.     6.594]
#  [ 3.     4.083]
#  [ 3.     7.543]
#  [ 4.     2.966]
#  [ 6.     7.283]
#  [ 7.     6.533]
#  [ 6.     7.775]
#  [ 4.     0.14 ]
#  [ 6.     2.754]
#  [ 6.     3.591]
#  [ 5.     1.557]
#  [ 4.     1.954]
#  [ 3.     2.061]
#  [ 4.     3.797]
#  [ 4.     4.779]
#  [ 3.     5.635]
#  [ 5.     3.913]
#  [ 6.     6.703]
#  [ 6.     4.13 ]
# ...

# %%
from datetime import date
from sklearn.impute import SimpleImputer
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import pandas as pd

'''
Utilizamos LabelEnconder para convertir a números los datos categóricos.
LabelEnconder codifica etiquetas de una característica categórica en valores numéricos entre 0 y el
número de clases menos 1. Una vez instanciado, el método fit lo entrena (creando el mapeado entre las etiquetas
y los números) y el método transform() transforma las etiquetas que se incluyan como argumento en los
números correspondientes. El método fit_transform realiza ambas acciones simultáneamente.
'''
df = pd.read_csv('archs/Datos.csv')
labelencoder_X = LabelEncoder()
X[:, 0] = labelencoder_X.fit_transform(X[:, 0])
print(X)
# Out:
# [[ 0.     4.508]
#  [ 1.     0.096]
#  [ 1.     3.133]
#  [ 3.     7.909]
#  [ 5.    70.811]
#  [ 3.     3.211]
#  [ 0.     6.063]
#  [ 2.     3.413]
#  [ 1.     4.41 ]
#  [ 0.     6.173]
#  [ 0.     7.353]
#  [ 4.     0.423]
#  [ 4.     4.218]
#  [ 0.     4.274]
#  [ 0.     2.908]
#  [ 1.     4.26 ]
#  [ 2.     5.719]
#  [ 5.     6.08 ]
#  [ 3.     7.711]
#  [ 5.     3.977]
#  [ 1.       nan]
#  [ 3.     6.126]
#  [ 2.     2.051]
#  [ 4.     4.875]
#  [ 1.     3.635]
#  [ 0.     1.407]
#  [ 4.     0.508]
#  [ 5.     4.378]
#  [ 2.     0.156]
#  [ 1.     1.299]
#  [ 5.     3.864]
#  [ 0.     1.923]
#  [ 5.     0.932]
#  [ 3.     6.594]
#  [ 0.     4.083]
#  [ 0.     7.543]
#  [ 1.     2.966]
#  [ 3.     7.283]
#  [ 4.     6.533]
#  [ 3.     7.775]
#  [ 1.     0.14 ]
#  [ 3.     2.754]
#  [ 3.     3.591]
#  [ 2.     1.557]
#  [ 1.     1.954]
#  [ 0.     2.061]
#  [ 1.     3.797]
#  [ 1.     4.779]
#  [ 0.     5.635]
#  [ 2.     3.913]
#  [ 3.     6.703]
#  [ 3.     4.13 ]
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
import pandas as pd
from sklearn.model_selection import train_test_split


df = pd.read_csv('archs/Datos.csv')
df.head()
X = df.iloc[:, :-1].values
labelencoder_X = LabelEncoder()
X[:, 0] = labelencoder_X.fit_transform(X[:, 0])
onehotencoder = make_column_transformer((OneHotEncoder(), [0]), remainder = "passthrough")
X = onehotencoder.fit_transform(X)
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)
y
X_train = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
y_train = train_test_split(X, y, test_size = 0.2, random_state = 0)
y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 17
#      15 y = labelencoder_y.fit_transform(y)
#      16 y
# ---> 17 X_train = train_test_split(X, y, test_size = 0.2, random_state = 0)
#      18 X_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
#      19 y_train = train_test_split(X, y, test_size = 0.2, random_state = 0)
#
# File c:\Users\ivaga\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
# ...
